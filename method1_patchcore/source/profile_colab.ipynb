# %%
# !pip install -q faiss-gpu-cu12
# !pip install -q click pretrainedmodels scikit-image scikit-learn scipy tqdm psutil pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 MB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done

# %%
import torch, faiss
print("PyTorch 버전:", torch.__version__)
print("GPU 사용 가능 여부:", torch.cuda.is_available())
print("FAISS 버전:", faiss.__version__)
# Out:
# PyTorch 버전: 2.11.0+cu128
# GPU 사용 가능 여부: True
# FAISS 버전: 1.14.1

# %%
# !git clone https://github.com/amazon-science/patchcore-inspection.git
# %cd patchcore-inspection
# Out:
# Cloning into 'patchcore-inspection'...
# remote: Enumerating objects: 365, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 365 (delta 13), reused 8 (delta 8), pack-reused 329 (from 1)
# Receiving objects: 100% (365/365), 2.02 MiB | 33.92 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# Filtering content: 100% (360/360), 2.14 GiB | 46.28 MiB/s, done.
# /content/patchcore-inspection

# %%
from google.colab import drive
drive.mount('/content/drive')

DATA_PATH = "/content/drive/MyDrive/anormaly_detection/mvtec"
# Out:
# Mounted at /content/drive

# %%
import os
drive_script_path = "/content/drive/MyDrive/profile_baseline.py"
colab_script_path = "bin/profile_baseline.py"

if os.path.exists(drive_script_path):
    # !cp {drive_script_path} {colab_script_path}
    print("성공적으로 Google Drive에서 profile_baseline.py 파일을 복사하였습니다!")
else:
    print(f"드라이브 경로에 파일이 존재하지 않습니다: {drive_script_path}")
    print("왼쪽 파일 탐색기에서 bin/ 디렉토리 내에 직접 profile_baseline.py 파일을 만들어 아래 코드를 붙여넣어주세요.")
# Out:
# 성공적으로 Google Drive에서 profile_baseline.py 파일을 복사하였습니다!

# %%
CATEGORY = "bottle"
import torch
GPU_FLAG = 0 if torch.cuda.is_available() else -1
# !PYTHONPATH=src python bin/profile_baseline.py \
    --gpu {GPU_FLAG} \
    --seed 0 \
    results_profile \
    patch_core \
    -b wideresnet50 \
    -le layer2 \
    -le layer3 \
    --pretrain_embed_dimension 1024 \
    --target_embed_dimension 1024 \
    --anomaly_scorer_num_nn 1 \
    --patchsize 3 \
    sampler \
    -p 0.1 approx_greedy_coreset \
    dataset \
    --resize 256 \
    --imagesize 224 \
    -d {CATEGORY} \
    mvtec {DATA_PATH}
# Out:
# INFO:__main__:Command line arguments: bin/profile_baseline.py --gpu 0 --seed 0 results_profile patch_core -b wideresnet50 -le layer2 -le layer3 --pretrain_embed_dimension 1024 --target_embed_dimension 1024 --anomaly_scorer_num_nn 1 --patchsize 3 sampler -p 0.1 approx_greedy_coreset dataset --resize 256 --imagesize 224 -d bottle mvtec /content/drive/MyDrive/anormaly_detection/mvtec
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# INFO:__main__:Evaluating dataset [mvtec_bottle] (1/1)...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Wide_ResNet50_2_Weights.IMAGENET1K_V1`. You can also use `weights=Wide_ResNet50_2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# INFO:__main__:Training models (1/1)
#
# Computing support features...:   0% 0/105 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Computing support features...:  83% 87/105 [00:10<00:02,  6.11it/s]
# Computing support features...:  84% 88/105 [00:10<00:02,  5.89it/s]
# Computing support features...:  85% 89/105 [00:10<00:02,  5.81it/s]
# Computing support features...:  87% 91/105 [00:10<00:01,  7.37it/s]
# Computing support features...:  89% 93/105 [00:10<00:01,  8.59it/s]
# Computing support features...:  90% 95/105 [00:11<00:01,  9.51it/s]
# Computing support features...:  92% 97/105 [00:11<00:00, 10.21it/s]
# Computing support features...:  94% 99/105 [00:11<00:00, 10.58it/s]
# Computing support features...:  96% 101/105 [00:11<00:00, 10.91it/s]
# Computing support features...:  98% 103/105 [00:11<00:00, 11.34it/s]
# Computing support features...: 100% 105/105 [00:11<00:00, 12.37it/s]
# Subsampling...: 100% 16385/16385 [00:20<00:00, 786.22it/s]
# INFO:__main__:Embedding test data with models (1/1)
# INFO:__main__:Computing evaluation metrics.
# INFO:__main__:instance_auroc: 1.000
# INFO:__main__:full_pixel_auroc: 0.985
# INFO:__main__:anomaly_pixel_auroc: 0.980
# INFO:__main__:
# ==========================================
# INFO:__main__:--- Profiling Results for mvtec_bottle ---
# INFO:__main__:Num Train Images: 209, Num Test Images: 83
# INFO:__main__:Train Feature Extraction: 11.9728 s | 173.7031 MB
# INFO:__main__:Memory Bank Build:        22.6190 s | 755.0796 MB
# INFO:__main__:Test Feature Extraction:  4.0748 s (49.09 ms/img) | 172.1719 MB
# INFO:__main__:kNN Search:               38.4390 s (463.12 ms/img) | 0.0000 MB
# INFO:__main__:Post-processing:          0.2444 s (2.94 ms/img) | 0.3892 MB
# INFO:__main__:Total Test Inference:     42.7581 s (515.16 ms/img)
# INFO:__main__:==========================================
#
# INFO:__main__:
#
# -----
#
# INFO:patchcore.utils:instance_auroc: 1.000
# INFO:patchcore.utils:full_pixel_auroc: 0.985
# INFO:patchcore.utils:anomaly_pixel_auroc: 0.980

# %%
CATEGORY = "metal_nut"
import torch
GPU_FLAG = 0 if torch.cuda.is_available() else -1
# !PYTHONPATH=src python bin/profile_baseline.py \
    --gpu {GPU_FLAG} \
    --seed 0 \
    results_profile \
    patch_core \
    -b wideresnet50 \
    -le layer2 \
    -le layer3 \
    --pretrain_embed_dimension 1024 \
    --target_embed_dimension 1024 \
    --anomaly_scorer_num_nn 1 \
    --patchsize 3 \
    sampler \
    -p 0.1 approx_greedy_coreset \
    dataset \
    --resize 256 \
    --imagesize 224 \
    -d {CATEGORY} \
    mvtec {DATA_PATH}
# Out:
# INFO:__main__:Command line arguments: bin/profile_baseline.py --gpu 0 --seed 0 results_profile patch_core -b wideresnet50 -le layer2 -le layer3 --pretrain_embed_dimension 1024 --target_embed_dimension 1024 --anomaly_scorer_num_nn 1 --patchsize 3 sampler -p 0.1 approx_greedy_coreset dataset --resize 256 --imagesize 224 -d metal_nut mvtec /content/drive/MyDrive/anormaly_detection/mvtec
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# INFO:__main__:Evaluating dataset [mvtec_metal_nut] (1/1)...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Wide_ResNet50_2_Weights.IMAGENET1K_V1`. You can also use `weights=Wide_ResNet50_2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Computing support features...:  58% 64/110 [00:09<00:06,  6.88it/s]
# Computing support features...:  60% 66/110 [00:10<00:05,  8.01it/s]
# Computing support features...:  61% 67/110 [00:10<00:06,  6.17it/s]
# Computing support features...:  62% 68/110 [00:11<00:12,  3.30it/s]
# Computing support features...:  63% 69/110 [00:11<00:10,  3.96it/s]
# Computing support features...:  64% 70/110 [00:11<00:08,  4.73it/s]
# Computing support features...:  65% 72/110 [00:11<00:06,  6.07it/s]
# Computing support features...:  66% 73/110 [00:11<00:06,  6.14it/s]
# Computing support features...:  67% 74/110 [00:11<00:05,  6.53it/s]
# Computing support features...:  69% 76/110 [00:12<00:04,  7.37it/s]
# Computing support features...:  70% 77/110 [00:12<00:06,  5.49it/s]
# Computing support features...:  71% 78/110 [00:12<00:05,  5.84it/s]
# Computing support features...:  73% 80/110 [00:12<00:04,  7.04it/s]
# Computing support features...:  75% 82/110 [00:12<00:03,  8.18it/s]
# Computing support features...:  76% 84/110 [00:13<00:02,  8.95it/s]
# Computing support features...:  78% 86/110 [00:13<00:02,  9.60it/s]
# Computing support features...:  80% 88/110 [00:13<00:02, 10.20it/s]
# Computing support features...:  82% 90/110 [00:13<00:01, 10.93it/s]
# Computing support features...:  84% 92/110 [00:13<00:01, 10.42it/s]
# Computing support features...:  85% 94/110 [00:13<00:01, 10.86it/s]
# Computing support features...:  87% 96/110 [00:14<00:01, 11.86it/s]
# Computing support features...:  89% 98/110 [00:14<00:00, 12.86it/s]
# Computing support features...:  91% 100/110 [00:14<00:00, 13.65it/s]
# Computing support features...:  93% 102/110 [00:14<00:00, 14.25it/s]
# Computing support features...:  95% 104/110 [00:14<00:00, 14.89it/s]
# Computing support features...:  96% 106/110 [00:14<00:00, 15.51it/s]
# Computing support features...:  98% 108/110 [00:14<00:00, 15.43it/s]
# Computing support features...: 100% 110/110 [00:14<00:00, 15.90it/s]
# Subsampling...: 100% 17248/17248 [00:23<00:00, 734.20it/s]
# INFO:__main__:Embedding test data with models (1/1)
# INFO:__main__:Computing evaluation metrics.
# INFO:__main__:instance_auroc: 0.999
# INFO:__main__:full_pixel_auroc: 0.983
# INFO:__main__:anomaly_pixel_auroc: 0.979
# INFO:__main__:
# ==========================================
# INFO:__main__:--- Profiling Results for mvtec_metal_nut ---
# INFO:__main__:Num Train Images: 220, Num Test Images: 115
# INFO:__main__:Train Feature Extraction: 15.0486 s | 173.7031 MB
# INFO:__main__:Memory Bank Build:        25.0662 s | 794.5078 MB
# INFO:__main__:Test Feature Extraction:  5.2247 s (45.43 ms/img) | 168.0000 MB
# INFO:__main__:kNN Search:               54.5556 s (474.40 ms/img) | 0.0000 MB
# INFO:__main__:Post-processing:          0.3468 s (3.02 ms/img) | 0.3892 MB
# INFO:__main__:Total Test Inference:     60.1271 s (522.84 ms/img)
# INFO:__main__:==========================================
#
# INFO:__main__:
#
# -----
#
# INFO:patchcore.utils:instance_auroc: 0.999
# INFO:patchcore.utils:full_pixel_auroc: 0.983
# INFO:patchcore.utils:anomaly_pixel_auroc: 0.979
